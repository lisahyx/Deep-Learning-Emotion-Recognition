# %%
# !pip install numpy
# !pip install scipy
# !pip install mne
# !pip install glob
# !pip install pandas
# !pip install xlrd
# !pip install mne_features
# !pip install ipynb
# !pip install pickle
# !pip install tensorflow
# !pip install matplotlib	
# !pip install featurewiz
# !pip install plotly
# !pip install dash_bootstrap_components
# !pip install jupyter_dash
# !pip install dash_mantine_components
# !pip install dash_iconify	
# !pip install unittest
# !pip install gdown
# !pip install os
# Out:
# Requirement already satisfied: numpy in c:\users\gwen\anaconda3\lib\site-packages (1.20.3)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scipy in c:\users\gwen\anaconda3\lib\site-packages (1.7.1)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in c:\users\gwen\anaconda3\lib\site-packages (from scipy) (1.20.3)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: mne in c:\users\gwen\anaconda3\lib\site-packages (1.2.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\gwen\anaconda3\lib\site-packages (from mne) (1.20.3)
# Requirement already satisfied: pooch>=1.5 in c:\users\gwen\anaconda3\lib\site-packages (from mne) (1.6.0)
# Requirement already satisfied: matplotlib in c:\users\gwen\anaconda3\lib\site-packages (from mne) (3.4.3)
# Requirement already satisfied: packaging in c:\users\gwen\anaconda3\lib\site-packages (from mne) (21.0)
# Requirement already satisfied: tqdm in c:\users\gwen\anaconda3\lib\site-packages (from mne) (4.62.3)
# Requirement already satisfied: jinja2 in c:\users\gwen\anaconda3\lib\site-packages (from mne) (2.11.3)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\gwen\anaconda3\lib\site-packages (from mne) (1.7.1)
# Requirement already satisfied: decorator in c:\users\gwen\anaconda3\lib\site-packages (from mne) (5.1.0)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\gwen\anaconda3\lib\site-packages (from pooch>=1.5->mne) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\gwen\anaconda3\lib\site-packages (from pooch>=1.5->mne) (2.26.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\gwen\anaconda3\lib\site-packages (from packaging->mne) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\gwen\anaconda3\lib\site-packages (from jinja2->mne) (1.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gwen\anaconda3\lib\site-packages (from matplotlib->mne) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gwen\anaconda3\lib\site-packages (from matplotlib->mne) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gwen\anaconda3\lib\site-packages (from matplotlib->mne) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gwen\anaconda3\lib\site-packages (from matplotlib->mne) (2.8.2)
# Requirement already satisfied: colorama in c:\users\gwen\anaconda3\lib\site-packages (from tqdm->mne) (0.4.4)
# Requirement already satisfied: six in c:\users\gwen\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->mne) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gwen\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gwen\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gwen\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (1.26.7)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement glob (from versions: none)
# ERROR: No matching distribution found for glob
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\gwen\anaconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gwen\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gwen\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\gwen\anaconda3\lib\site-packages (from pandas) (1.20.3)
# Requirement already satisfied: six>=1.5 in c:\users\gwen\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: xlrd in c:\users\gwen\anaconda3\lib\site-packages (2.0.1)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: mne_features in c:\users\gwen\anaconda3\lib\site-packages (0.2.1)
# Requirement already satisfied: scipy in c:\users\gwen\anaconda3\lib\site-packages (from mne_features) (1.7.1)
# Requirement already satisfied: PyWavelets in c:\users\gwen\anaconda3\lib\site-packages (from mne_features) (1.1.1)
# Requirement already satisfied: scikit-learn in c:\users\gwen\anaconda3\lib\site-packages (from mne_features) (1.2.1)
# Requirement already satisfied: mne in c:\users\gwen\anaconda3\lib\site-packages (from mne_features) (1.2.1)
# Requirement already satisfied: pandas in c:\users\gwen\anaconda3\lib\site-packages (from mne_features) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gwen\anaconda3\lib\site-packages (from mne_features) (1.20.3)
# Requirement already satisfied: numba in c:\users\gwen\anaconda3\lib\site-packages (from mne_features) (0.54.1)
# Requirement already satisfied: matplotlib in c:\users\gwen\anaconda3\lib\site-packages (from mne->mne_features) (3.4.3)
# Requirement already satisfied: jinja2 in c:\users\gwen\anaconda3\lib\site-packages (from mne->mne_features) (2.11.3)
# Requirement already satisfied: pooch>=1.5 in c:\users\gwen\anaconda3\lib\site-packages (from mne->mne_features) (1.6.0)
# Requirement already satisfied: decorator in c:\users\gwen\anaconda3\lib\site-packages (from mne->mne_features) (5.1.0)
# Requirement already satisfied: tqdm in c:\users\gwen\anaconda3\lib\site-packages (from mne->mne_features) (4.62.3)
# Requirement already satisfied: packaging in c:\users\gwen\anaconda3\lib\site-packages (from mne->mne_features) (21.0)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in c:\users\gwen\anaconda3\lib\site-packages (from numba->mne_features) (0.37.0)
# Requirement already satisfied: setuptools in c:\users\gwen\anaconda3\lib\site-packages (from numba->mne_features) (58.0.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gwen\anaconda3\lib\site-packages (from pandas->mne_features) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gwen\anaconda3\lib\site-packages (from pandas->mne_features) (2021.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\gwen\anaconda3\lib\site-packages (from scikit-learn->mne_features) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from scikit-learn->mne_features) (2.2.0)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\gwen\anaconda3\lib\site-packages (from pooch>=1.5->mne->mne_features) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\gwen\anaconda3\lib\site-packages (from pooch>=1.5->mne->mne_features) (2.26.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\gwen\anaconda3\lib\site-packages (from packaging->mne->mne_features) (3.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\gwen\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->mne_features) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\gwen\anaconda3\lib\site-packages (from jinja2->mne->mne_features) (1.1.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gwen\anaconda3\lib\site-packages (from matplotlib->mne->mne_features) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gwen\anaconda3\lib\site-packages (from matplotlib->mne->mne_features) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gwen\anaconda3\lib\site-packages (from matplotlib->mne->mne_features) (1.3.1)
# Requirement already satisfied: colorama in c:\users\gwen\anaconda3\lib\site-packages (from tqdm->mne->mne_features) (0.4.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne->mne_features) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gwen\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne->mne_features) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gwen\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne->mne_features) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gwen\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne->mne_features) (2021.10.8)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: ipynb in c:\users\gwen\anaconda3\lib\site-packages (0.5.1)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tensorflow in c:\users\gwen\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (0.27.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (1.50.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (1.20.3)
# Requirement already satisfied: setuptools in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: packaging in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (21.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\gwen\anaconda3\lib\site-packages (from tensorflow) (22.10.26)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\gwen\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\gwen\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\gwen\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\gwen\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\gwen\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\gwen\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.26.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\gwen\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\gwen\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.14.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\gwen\anaconda3\lib\site-packages (from packaging->tensorflow) (3.0.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\gwen\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\gwen\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\gwen\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\gwen\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (4.8.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gwen\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gwen\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gwen\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.7)
# Requirement already satisfied: zipp>=0.5 in c:\users\gwen\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\gwen\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.2)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\gwen\anaconda3\lib\site-packages (3.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gwen\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.16 in c:\users\gwen\anaconda3\lib\site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gwen\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gwen\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gwen\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\gwen\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: six in c:\users\gwen\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: featurewiz in c:\users\gwen\appdata\roaming\python\python39\site-packages (0.2.3)
# Requirement already satisfied: lightgbm>=3.2.1 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from featurewiz) (3.3.3)
# Requirement already satisfied: Pillow>=9.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from featurewiz) (9.4.0)
# Requirement already satisfied: imbalanced-learn>=0.7 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from featurewiz) (0.9.1)
# Requirement already satisfied: scikit-learn>=0.24 in c:\users\gwen\anaconda3\lib\site-packages (from featurewiz) (1.2.1)
# Requirement already satisfied: pandas>=1.3.4 in c:\users\gwen\anaconda3\lib\site-packages (from featurewiz) (1.3.4)
# Requirement already satisfied: seaborn in c:\users\gwen\appdata\roaming\python\python39\site-packages (from featurewiz) (0.12.1)
# Requirement already satisfied: matplotlib in c:\users\gwen\anaconda3\lib\site-packages (from featurewiz) (3.4.3)
# Requirement already satisfied: feather-format>=0.4.1 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from featurewiz) (0.4.1)
# Requirement already satisfied: distributed>=2021.11.0 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from featurewiz) (2022.12.0)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from featurewiz) (2.5.1.post0)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\gwen\anaconda3\lib\site-packages (from featurewiz) (4.62.3)
# Requirement already satisfied: xlrd>=2.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from featurewiz) (2.0.1)
# Requirement already satisfied: ipython in c:\users\gwen\anaconda3\lib\site-packages (from featurewiz) (7.29.0)
# Requirement already satisfied: fsspec>=0.3.3 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from featurewiz) (2022.11.0)
# Requirement already satisfied: xgboost>=1.5.1 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from featurewiz) (1.7.1)
# Requirement already satisfied: dask>=2021.11.0 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from featurewiz) (2022.12.0)
# Requirement already satisfied: jupyter in c:\users\gwen\appdata\roaming\python\python39\site-packages (from featurewiz) (1.0.0)
# Requirement already satisfied: pyarrow~=7.0.0 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from featurewiz) (7.0.0)
# Requirement already satisfied: networkx>=2.6.2 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from featurewiz) (2.8.8)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from category-encoders>=2.4.0->featurewiz) (0.5.3)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\gwen\anaconda3\lib\site-packages (from category-encoders>=2.4.0->featurewiz) (1.20.3)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from category-encoders>=2.4.0->featurewiz) (1.7.1)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from category-encoders>=2.4.0->featurewiz) (0.13.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\gwen\anaconda3\lib\site-packages (from dask>=2021.11.0->featurewiz) (21.0)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from dask>=2021.11.0->featurewiz) (0.12.0)
# Requirement already satisfied: click>=7.0 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from dask>=2021.11.0->featurewiz) (8.1.3)
# Requirement already satisfied: partd>=0.3.10 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from dask>=2021.11.0->featurewiz) (1.3.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from dask>=2021.11.0->featurewiz) (2.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from dask>=2021.11.0->featurewiz) (6.0)
# Requirement already satisfied: tornado>=6.0.3 in c:\users\gwen\anaconda3\lib\site-packages (from distributed>=2021.11.0->featurewiz) (6.1)
# Requirement already satisfied: zict>=0.1.3 in c:\users\gwen\anaconda3\lib\site-packages (from distributed>=2021.11.0->featurewiz) (2.0.0)
# Requirement already satisfied: jinja2 in c:\users\gwen\anaconda3\lib\site-packages (from distributed>=2021.11.0->featurewiz) (2.11.3)
# Requirement already satisfied: urllib3 in c:\users\gwen\anaconda3\lib\site-packages (from distributed>=2021.11.0->featurewiz) (1.26.7)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in c:\users\gwen\anaconda3\lib\site-packages (from distributed>=2021.11.0->featurewiz) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from distributed>=2021.11.0->featurewiz) (1.7.0)
# Requirement already satisfied: psutil>=5.0 in c:\users\gwen\anaconda3\lib\site-packages (from distributed>=2021.11.0->featurewiz) (5.8.0)
# Requirement already satisfied: msgpack>=0.6.0 in c:\users\gwen\anaconda3\lib\site-packages (from distributed>=2021.11.0->featurewiz) (1.0.2)
# Requirement already satisfied: locket>=1.0.0 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from distributed>=2021.11.0->featurewiz) (1.0.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from imbalanced-learn>=0.7->featurewiz) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from imbalanced-learn>=0.7->featurewiz) (2.2.0)
# Requirement already satisfied: wheel in c:\users\gwen\anaconda3\lib\site-packages (from lightgbm>=3.2.1->featurewiz) (0.37.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gwen\anaconda3\lib\site-packages (from pandas>=1.3.4->featurewiz) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gwen\anaconda3\lib\site-packages (from pandas>=1.3.4->featurewiz) (2021.3)
# Requirement already satisfied: colorama in c:\users\gwen\anaconda3\lib\site-packages (from tqdm>=4.62.0->featurewiz) (0.4.4)
# Requirement already satisfied: decorator in c:\users\gwen\anaconda3\lib\site-packages (from ipython->featurewiz) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from ipython->featurewiz) (3.0.20)
# Requirement already satisfied: backcall in c:\users\gwen\anaconda3\lib\site-packages (from ipython->featurewiz) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\gwen\anaconda3\lib\site-packages (from ipython->featurewiz) (5.1.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\gwen\anaconda3\lib\site-packages (from ipython->featurewiz) (0.18.0)
# Requirement already satisfied: pickleshare in c:\users\gwen\anaconda3\lib\site-packages (from ipython->featurewiz) (0.7.5)
# Requirement already satisfied: pygments in c:\users\gwen\anaconda3\lib\site-packages (from ipython->featurewiz) (2.10.0)
# Requirement already satisfied: matplotlib-inline in c:\users\gwen\anaconda3\lib\site-packages (from ipython->featurewiz) (0.1.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\gwen\anaconda3\lib\site-packages (from ipython->featurewiz) (58.0.4)
# Requirement already satisfied: qtconsole in c:\users\gwen\appdata\roaming\python\python39\site-packages (from jupyter->featurewiz) (5.4.0)
# Requirement already satisfied: ipywidgets in c:\users\gwen\appdata\roaming\python\python39\site-packages (from jupyter->featurewiz) (8.0.3)
# Requirement already satisfied: jupyter-console in c:\users\gwen\appdata\roaming\python\python39\site-packages (from jupyter->featurewiz) (6.4.4)
# Requirement already satisfied: nbconvert in c:\users\gwen\anaconda3\lib\site-packages (from jupyter->featurewiz) (6.1.0)
# Requirement already satisfied: notebook in c:\users\gwen\anaconda3\lib\site-packages (from jupyter->featurewiz) (6.4.5)
# Requirement already satisfied: ipykernel in c:\users\gwen\anaconda3\lib\site-packages (from jupyter->featurewiz) (6.4.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gwen\anaconda3\lib\site-packages (from matplotlib->featurewiz) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\gwen\anaconda3\lib\site-packages (from matplotlib->featurewiz) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\gwen\anaconda3\lib\site-packages (from matplotlib->featurewiz) (0.10.0)
# Requirement already satisfied: six in c:\users\gwen\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->featurewiz) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\gwen\anaconda3\lib\site-packages (from jedi>=0.16->ipython->featurewiz) (0.8.2)
# Requirement already satisfied: wcwidth in c:\users\gwen\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->featurewiz) (0.2.5)
# Collecting packaging>=20.0
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
#      -------------------------------------- 48.9/48.9 kB 613.7 kB/s eta 0:00:00
# Requirement already satisfied: heapdict in c:\users\gwen\anaconda3\lib\site-packages (from zict>=0.1.3->distributed>=2021.11.0->featurewiz) (1.0.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from ipykernel->jupyter->featurewiz) (1.4.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\gwen\anaconda3\lib\site-packages (from ipykernel->jupyter->featurewiz) (6.1.12)
# Requirement already satisfied: ipython-genutils in c:\users\gwen\anaconda3\lib\site-packages (from ipykernel->jupyter->featurewiz) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from ipywidgets->jupyter->featurewiz) (3.0.4)
# Collecting widgetsnbextension~=4.0
#   Downloading widgetsnbextension-4.0.7-py3-none-any.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\gwen\anaconda3\lib\site-packages (from jinja2->distributed>=2021.11.0->featurewiz) (1.1.1)
# Collecting jupyter-client<8.0
#   Downloading jupyter_client-7.4.9-py3-none-any.whl (133 kB)
#      -------------------------------------- 133.5/133.5 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: bleach in c:\users\gwen\anaconda3\lib\site-packages (from nbconvert->jupyter->featurewiz) (4.0.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\gwen\anaconda3\lib\site-packages (from nbconvert->jupyter->featurewiz) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\gwen\anaconda3\lib\site-packages (from nbconvert->jupyter->featurewiz) (0.5.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\gwen\anaconda3\lib\site-packages (from nbconvert->jupyter->featurewiz) (0.3)
# Requirement already satisfied: jupyter-core in c:\users\gwen\anaconda3\lib\site-packages (from nbconvert->jupyter->featurewiz) (4.8.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\gwen\anaconda3\lib\site-packages (from nbconvert->jupyter->featurewiz) (0.8.4)
# Requirement already satisfied: testpath in c:\users\gwen\anaconda3\lib\site-packages (from nbconvert->jupyter->featurewiz) (0.5.0)
# Requirement already satisfied: defusedxml in c:\users\gwen\anaconda3\lib\site-packages (from nbconvert->jupyter->featurewiz) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\gwen\anaconda3\lib\site-packages (from nbconvert->jupyter->featurewiz) (1.4.3)
# Requirement already satisfied: nbformat>=4.4 in c:\users\gwen\anaconda3\lib\site-packages (from nbconvert->jupyter->featurewiz) (5.1.3)
# Requirement already satisfied: pyzmq>=17 in c:\users\gwen\anaconda3\lib\site-packages (from notebook->jupyter->featurewiz) (22.2.1)
# Requirement already satisfied: argon2-cffi in c:\users\gwen\anaconda3\lib\site-packages (from notebook->jupyter->featurewiz) (20.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\gwen\anaconda3\lib\site-packages (from notebook->jupyter->featurewiz) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\gwen\anaconda3\lib\site-packages (from notebook->jupyter->featurewiz) (0.9.4)
# Requirement already satisfied: prometheus-client in c:\users\gwen\anaconda3\lib\site-packages (from notebook->jupyter->featurewiz) (0.11.0)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from qtconsole->jupyter->featurewiz) (2.3.0)
# Collecting tornado>=6.0.3
#   Downloading tornado-6.3-cp38-abi3-win_amd64.whl (427 kB)
#      -------------------------------------- 427.9/427.9 kB 4.4 MB/s eta 0:00:00
# Collecting pyzmq>=17
#   Downloading pyzmq-25.0.2-cp39-cp39-win_amd64.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 840.6 kB/s eta 0:00:00
# Collecting nest-asyncio>=1.5.4
#   Using cached nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
# Collecting jupyter-core
#   Downloading jupyter_core-5.3.0-py3-none-any.whl (93 kB)
#      ---------------------------------------- 93.2/93.2 kB 1.1 MB/s eta 0:00:00
# Collecting traitlets>=4.2
#   Downloading traitlets-5.9.0-py3-none-any.whl (117 kB)
#      -------------------------------------- 117.4/117.4 kB 1.1 MB/s eta 0:00:00
# Collecting platformdirs>=2.5
#   Downloading platformdirs-3.2.0-py3-none-any.whl (14 kB)
# Collecting pywin32>=300
#   Downloading pywin32-306-cp39-cp39-win_amd64.whl (9.3 MB)
#      ---------------------------------------- 9.3/9.3 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: async-generator in c:\users\gwen\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->featurewiz) (1.10)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\gwen\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert->jupyter->featurewiz) (3.2.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\gwen\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->featurewiz) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter->featurewiz) (1.14.6)
# Requirement already satisfied: webencodings in c:\users\gwen\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->featurewiz) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\gwen\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->featurewiz) (2.20)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\gwen\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter->featurewiz) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\gwen\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter->featurewiz) (0.18.0)
# Installing collected packages: pywin32, widgetsnbextension, traitlets, tornado, pyzmq, platformdirs, packaging, nest-asyncio, jupyter-core, jupyter-client
#   Attempting uninstall: pywin32
#     Found existing installation: pywin32 228
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Gwen\\anaconda3\\Lib\\site-packages\\pywin32_system32\\pywintypes39.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#     Uninstalling pywin32-228:
#       Successfully uninstalled pywin32-228
#   Rolling back uninstall of pywin32
#   Moving to c:\users\gwen\anaconda3\lib\site-packages\__pycache__\pythoncom.cpython-39.pyc
#    from C:\Users\Gwen\AppData\Local\Temp\pip-uninstall-3987oio7\pythoncom.cpython-39.pyc
#   Moving to c:\users\gwen\anaconda3\lib\site-packages\adodbapi
#    from C:\Users\Gwen\anaconda3\Lib\site-packages\~dodbapi
#   Moving to c:\users\gwen\anaconda3\lib\site-packages\isapi
#    from C:\Users\Gwen\anaconda3\Lib\site-packages\~sapi
#   Moving to c:\users\gwen\anaconda3\lib\site-packages\pythoncom.py
#    from C:\Users\Gwen\AppData\Local\Temp\pip-uninstall-fu31g1u1\pythoncom.py
#   Moving to c:\users\gwen\anaconda3\lib\site-packages\pythonwin
#    from C:\Users\Gwen\anaconda3\Lib\site-packages\~ythonwin
#   Moving to c:\users\gwen\anaconda3\lib\site-packages\pywin32-228-py3.9.egg-info
#    from C:\Users\Gwen\anaconda3\Lib\site-packages\~ywin32-228-py3.9.egg-info
#   Moving to c:\users\gwen\anaconda3\lib\site-packages\win32\lib\
#    from C:\Users\Gwen\anaconda3\Lib\site-packages\win32\~ib
#   Moving to c:\users\gwen\anaconda3\lib\site-packages\win32com
#    from C:\Users\Gwen\anaconda3\Lib\site-packages\~in32com
#   Moving to c:\users\gwen\anaconda3\lib\site-packages\win32comext
#    from C:\Users\Gwen\anaconda3\Lib\site-packages\~in32comext
# Requirement already satisfied: plotly in c:\users\gwen\anaconda3\lib\site-packages (5.13.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\gwen\anaconda3\lib\site-packages (from plotly) (8.1.0)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: dash_bootstrap_components in c:\users\gwen\anaconda3\lib\site-packages (1.3.1)
# Requirement already satisfied: dash>=2.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from dash_bootstrap_components) (2.8.1)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\gwen\anaconda3\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (1.1.2)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (5.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (5.13.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (2.0.0)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\gwen\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\gwen\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (2.0.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\gwen\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (8.1.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\gwen\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=2.0.0->dash_bootstrap_components) (8.1.0)
# Requirement already satisfied: colorama in c:\users\gwen\anaconda3\lib\site-packages (from click>=5.1->Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\gwen\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (1.1.1)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: jupyter_dash in c:\users\gwen\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: dash in c:\users\gwen\anaconda3\lib\site-packages (from jupyter_dash) (2.8.1)
# Requirement already satisfied: nest-asyncio in c:\users\gwen\anaconda3\lib\site-packages (from jupyter_dash) (1.5.1)
# Requirement already satisfied: ipython in c:\users\gwen\anaconda3\lib\site-packages (from jupyter_dash) (7.29.0)
# Requirement already satisfied: ipykernel in c:\users\gwen\anaconda3\lib\site-packages (from jupyter_dash) (6.4.1)
# Requirement already satisfied: requests in c:\users\gwen\anaconda3\lib\site-packages (from jupyter_dash) (2.26.0)
# Requirement already satisfied: retrying in c:\users\gwen\anaconda3\lib\site-packages (from jupyter_dash) (1.3.4)
# Requirement already satisfied: flask in c:\users\gwen\anaconda3\lib\site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: ansi2html in c:\users\gwen\anaconda3\lib\site-packages (from jupyter_dash) (1.8.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from dash->jupyter_dash) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from dash->jupyter_dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.13.0)
# Requirement already satisfied: click>=5.1 in c:\users\gwen\appdata\roaming\python\python39\site-packages (from flask->jupyter_dash) (8.1.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\gwen\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\gwen\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\gwen\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.11.3)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (1.4.1)
# Requirement already satisfied: ipython-genutils in c:\users\gwen\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (0.2.0)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in c:\users\gwen\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.1.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\gwen\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\gwen\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (0.1.2)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\gwen\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: setuptools>=18.5 in c:\users\gwen\anaconda3\lib\site-packages (from ipython->jupyter_dash) (58.0.4)
# Requirement already satisfied: colorama in c:\users\gwen\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.4.4)
# Requirement already satisfied: backcall in c:\users\gwen\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: pygments in c:\users\gwen\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.10.0)
# Requirement already satisfied: pickleshare in c:\users\gwen\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\users\gwen\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.18.0)
# Requirement already satisfied: decorator in c:\users\gwen\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gwen\anaconda3\lib\site-packages (from requests->jupyter_dash) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gwen\anaconda3\lib\site-packages (from requests->jupyter_dash) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gwen\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.7)
# Requirement already satisfied: six>=1.7.0 in c:\users\gwen\anaconda3\lib\site-packages (from retrying->jupyter_dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\gwen\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\gwen\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (1.1.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\gwen\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (4.8.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\gwen\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\gwen\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (22.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\gwen\anaconda3\lib\site-packages (from plotly>=5.0.0->dash->jupyter_dash) (8.1.0)
# Requirement already satisfied: wcwidth in c:\users\gwen\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: pywin32>=1.0 in c:\users\gwen\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter_dash) (228)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: dash_mantine_components in c:\users\gwen\anaconda3\lib\site-packages (0.11.1)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: dash_iconify in c:\users\gwen\anaconda3\lib\site-packages (0.1.2)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement unittest (from versions: none)
# ERROR: No matching distribution found for unittest
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: gdown in c:\users\gwen\anaconda3\lib\site-packages (4.7.1)
# Requirement already satisfied: tqdm in c:\users\gwen\anaconda3\lib\site-packages (from gdown) (4.62.3)
# Requirement already satisfied: requests[socks] in c:\users\gwen\anaconda3\lib\site-packages (from gdown) (2.26.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\gwen\anaconda3\lib\site-packages (from gdown) (4.10.0)
# Requirement already satisfied: six in c:\users\gwen\anaconda3\lib\site-packages (from gdown) (1.16.0)
# Requirement already satisfied: filelock in c:\users\gwen\anaconda3\lib\site-packages (from gdown) (3.3.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\gwen\anaconda3\lib\site-packages (from beautifulsoup4->gdown) (2.2.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\gwen\anaconda3\lib\site-packages (from requests[socks]->gdown) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gwen\anaconda3\lib\site-packages (from requests[socks]->gdown) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gwen\anaconda3\lib\site-packages (from requests[socks]->gdown) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gwen\anaconda3\lib\site-packages (from requests[socks]->gdown) (1.26.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\gwen\anaconda3\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in c:\users\gwen\anaconda3\lib\site-packages (from tqdm->gdown) (0.4.4)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\gwen\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
